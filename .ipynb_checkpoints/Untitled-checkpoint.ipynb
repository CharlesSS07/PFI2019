# %%
import numpy as np
from GO import GO
from PPI import PPI
from PathManager import PathManager as PM
from ParamHandler import ParamHandler as PH
from AE import AE
from KNN import KNN
from Metrics import Metrics
#import tensorflow as tf

# %%
ph = PH()
pm = PM(ph)
go = GO(pm, ph)
ppi = PPI(pm, ph, batch_size=200)
ae = AE(pm, ph, ppi, learn_rate=0.0001)
# Out:
# (19576, 19576) 19000 576 float32

# %%
#ppi.pca()
ae.train(epochs=100)
# Out:
# Epoch: 0 0.07332498
# Epoch: 1 0.07097305
# Epoch: 2 0.066910945
# Epoch: 3 0.06298894
# Epoch: 4 0.05895606
# Epoch: 5 0.0550824
# Epoch: 6 0.051721368
# Epoch: 7 0.04850121
# Epoch: 8 0.045532633
# Epoch: 9 0.04274459
# Epoch: 10 0.040030476
# Epoch: 11 0.03745763
# Epoch: 12 0.03504347
# Epoch: 13 0.032757502
# Epoch: 14 0.030577641
# Epoch: 15 0.028550746
# Epoch: 16 0.026656128
# Epoch: 17 0.024873016
# Epoch: 18 0.02320252
# Epoch: 19 0.021593552
# Epoch: 20 0.020096589
# Epoch: 21 0.018676985
# Epoch: 22 0.017346477
# Epoch: 23 0.016088072
# Epoch: 24 0.014909133
# Epoch: 25 0.013809194
# Epoch: 26 0.012756574
# Epoch: 27 0.011768364
# Epoch: 28 0.0108271
# Epoch: 29 0.009954395
# Epoch: 30 0.009128701
# Epoch: 31 0.008356144
# Epoch: 32 0.007629524
# Epoch: 33 0.0069515877
# Epoch: 34 0.0063082376
# Epoch: 35 0.0057079648
# Epoch: 36 0.0051493216
# Epoch: 37 0.004628632
# Epoch: 38 0.0041381214
# Epoch: 39 0.0036806103
# Epoch: 40 0.0032553198
# Epoch: 41 0.0028676866
# Epoch: 42 0.0025091714
# Epoch: 43 0.0021804615
# Epoch: 44 0.0018771882
# Epoch: 45 0.001602935
# Epoch: 46 0.0013594916
# Epoch: 47 0.0011375854
# Epoch: 48 0.0009369937
# Epoch: 49 0.00076137454
# Epoch: 50 0.00060541974
# Epoch: 51 0.00047372494
# Epoch: 52 0.00036423665
# Epoch: 53 0.00027515335
# Epoch: 54 0.00020542997
# Epoch: 55 0.00015560845
# Epoch: 56 0.0001251414
# Epoch: 57 0.00011366891
# Epoch: 58 0.0001207997
# Epoch: 59 0.00013033568
# Epoch: 60 0.0001312862
# Epoch: 61 0.00013071806
# Epoch: 62 0.00013014277
# Epoch: 63 0.00012957944
# Epoch: 64 0.00012902627
# Epoch: 65 0.00012847547
# Epoch: 66 0.00012794758
# Epoch: 67 0.00012743063
# Epoch: 68 0.00012691545
# Epoch: 69 0.00012641346
# Epoch: 70 0.00012591426
# Epoch: 71 0.00012542379
# Epoch: 72 0.00012492757
# Epoch: 73 0.00012445242
# Epoch: 74 0.00012398753
# Epoch: 75 0.00012353015
# Epoch: 76 0.00012308321
# Epoch: 77 0.0001226431
# Epoch: 78 0.00012221289
# Epoch: 79 0.000121794816
# Epoch: 80 0.00012138382
# Epoch: 81 0.000120978184
# Epoch: 82 0.00012058115
# Epoch: 83 0.00012019593
# Epoch: 84 0.00011981173
# Epoch: 85 0.00011943996
# Epoch: 86 0.00011907957
# Epoch: 87 0.00011872693
# Epoch: 88 0.000118384334
# Epoch: 89 0.000118047625
# Epoch: 90 0.00011772233
# Epoch: 91 0.000117409334
# Epoch: 92 0.00011710162
# Epoch: 93 0.00011680089
# Epoch: 94 0.000116510135
# Epoch: 95 0.00011622847
# Epoch: 96 0.00011595463
# Epoch: 97 0.00011568824
# Epoch: 98 0.00011543125
# Epoch: 99 0.00011518312
# Epoch: 100 0.00011494356

# %%
c = ae.compress()

# %%
c.shape
# Out:
# (19576, 1, 2000)

# %%
d = (c[:,0]-c[:,0].mean())/np.std(c[:,0], axis=0)
d, d.shape
# Out:
# (array([1033819.56, 1036421.  , 1027270.75, ..., 1035202.9 , 1062217.9 ,
#         1034260.7 ], dtype=float32), (2000,))

# %%
c.sum(), ae.PPI.data.sum(), c.min(), c.shape
# Out:
# (54644433000000.0, 1.0987863e+17, 1687.6641, (19576, 1, 2000))

# %%
ae.save()

# %%
knn = KNN(pm, ph, go, c[:,0]/d, neighbor_count=10)

# %%
a = knn.predict()
# Out:
# finding nearest neighbors
# nearest neighbors found

# %%
met = Metrics(pm, ph, a, go)

# %%
met.run(show=True)
# Out:
# /home/shelby/.conda/envs/tensorflowgpu/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
ppi.data.shape
# Out:
# (19576, 19576)

# %%
met.thresholds.max(), met.thresholds.min()
# Out:
# (1.0, 0.0)

# %%
ph.save()

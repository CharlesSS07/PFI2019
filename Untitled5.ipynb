# %%
import pandas as pd
import numpy as np
import pylab as pl


file = 'models/March/31/output/log.tsv'


log = pd.read_csv(file, sep='\t')

np.unique(log.Stage)

def get_stage(S):
    return log[[s==S for s in log.Stage]]
# Out:
# array(['k1000pcac2000ae', 'k1000pcac2000ppca', 'k1000pcac2000ppca2',
#        'k1000pcac2000ppca2_knn', 'k1000pcac2000ppca2_oldknn', 'k10pcac10',
#        'k10pcac10ae', 'k10pcac10ppca', 'k10pcac10ppca_knn',
#        'k10pcac10ppca_knn_tmp', 'k10pcac2000ae', 'k10pcac2000ppca',
#        'k10pcac2000ppca_knn', 'k10pcac2000ppca_oldknn',
#        'new_ppca_c1000k2000', 'new_ppca_c100k2000', 'new_ppca_c10k2000',
#        'new_ppca_c2000k10', 'new_ppca_c2000k100', 'new_ppca_c2000k1000',
#        'new_ppca_c2000k1000_ae', 'new_ppca_c2000k1000_masked_01',
#        'new_ppca_c2000k1000_masked_03', 'new_ppca_c2000k1000_order1',
#        'new_ppca_c2000k100_ae', 'new_ppca_c2000k10_ae', 'unset'], dtype=object)

# %%
k1000pcac2000ae = get_stage('k1000pcac2000ae')

# %%
k10pcac2000ae = get_stage('k10pcac2000ae')

# %%
k10pcac10ae = get_stage('k10pcac10ae')

# %%
k10pcac10ppca = get_stage('k10pcac10ppca')

# %%
k1000pcac2000ppca = get_stage('k1000pcac2000ppca2')

# %%
k10pcac2000ppca = get_stage('k10pcac2000ppca')

# %%
new_ppca_c10k2000 = get_stage('new_ppca_c10k2000')

# %%
new_ppca_c100k2000 = get_stage('new_ppca_c100k2000')

# %%
new_ppca_c1000k2000 = get_stage('new_ppca_c1000k2000')

# %%
new_ppca_c2000k10 = get_stage('new_ppca_c2000k10')
new_ppca_c2000k100 = get_stage('new_ppca_c2000k100')
new_ppca_c2000k1000 = get_stage('new_ppca_c2000k1000')
new_ppca_c2000k10_ae = get_stage('new_ppca_c2000k10_ae')
new_ppca_c2000k100_ae = get_stage('new_ppca_c2000k100_ae')
new_ppca_c2000k1000_ae = get_stage('new_ppca_c2000k1000_ae')
new_ppca_c2000k1000_order1 = get_stage('new_ppca_c2000k1000_order1')
new_ppca_c2000k1000_masked_03 = get_stage('new_ppca_c2000k1000_masked_03')
new_ppca_c2000k1000_masked_01 = get_stage('new_ppca_c2000k1000_masked_01')

# %%
#pl.loglog(k10pcac2000ae.Ones, k10pcac2000ae.AUCPR1, 'or')
#pl.loglog(k1000pcac2000ae.Ones, k1000pcac2000ae.AUCPR1, 'og')
#pl.loglog(k1000pcac2000ppca.Ones, k1000pcac2000ppca.AUCPR1, 'ok')
#pl.loglog(k10pcac10ae.Ones, k10pcac10ae.AUCPR1, '+b')
pl.loglog(new_ppca_c10k2000.Ones, new_ppca_c10k2000.AUCPR1, 'ok')
pl.loglog(new_ppca_c100k2000.Ones, new_ppca_c100k2000.AUCPR1, 'or')
pl.loglog(new_ppca_c1000k2000.Ones, new_ppca_c1000k2000.AUCPR1, 'og')
pl.show()

# %%
#pl.loglog(new_ppca_c2000k10.Ones, new_ppca_c2000k10.AUCPR1, 'ok')
#pl.loglog(new_ppca_c2000k100.Ones, new_ppca_c2000k100.AUCPR1, 'or')
#pl.loglog(new_ppca_c2000k1000.Ones, new_ppca_c2000k1000.AUCPR1, 'og')
pl.subplot(1,2,1)
pl.loglog(new_ppca_c2000k1000_masked_01.Ones/16875, new_ppca_c2000k1000_masked_01.AUCPR1, 'ob')
pl.loglog(new_ppca_c2000k1000_masked_03.Ones/16875, new_ppca_c2000k1000_masked_03.AUCPR1, 'or')
pl.loglog(new_ppca_c2000k1000_order1.Ones/19576, new_ppca_c2000k1000_order1.AUCPR1, 'og')
pl.loglog(
    (10**-4, 1),
    (10**-4, 1)
)
pl.subplot(1,2,2)
pl.plot(new_ppca_c2000k1000_masked_01.Ones/16875, new_ppca_c2000k1000_masked_01.AUCPR1, 'ob')
pl.plot(new_ppca_c2000k1000_masked_03.Ones/16875, new_ppca_c2000k1000_masked_03.AUCPR1, 'or')
pl.plot(new_ppca_c2000k1000_order1.Ones/19576, new_ppca_c2000k1000_order1.AUCPR1, 'og')
pl.plot(
    (10**-4, 1),
    (10**-4, 1)
)
#pl.loglog(new_ppca_c2000k10_ae.Ones, new_ppca_c2000k10_ae.AUCPR1, '+k')
#pl.loglog(new_ppca_c2000k100_ae.Ones, new_ppca_c2000k100_ae.AUCPR1, '+r')
#pl.loglog(new_ppca_c2000k1000_ae.Ones, new_ppca_c2000k1000_ae.AUCPR1, '+g')
pl.show()

# %%
pl.loglog(new_ppca_c2000k1000.AUCPR1, new_ppca_c2000k1000_order1.AUCPR1, 'og')
pl.loglog(new_ppca_c2000k1000_masked_03.AUCPR1, new_ppca_c2000k1000_masked_01.AUCPR1, '+r')
pl.loglog(
    (10**-3, 1),
    (10**-3, 1)
)
pl.show()

# %%
pl.subplot?

# %%
pl.plot(new_ppca_c2000k1000.AUCPR1, new_ppca_c2000k1000_order1.AUCPR1, 'og')
pl.plot(new_ppca_c2000k1000_masked_03.AUCPR1, new_ppca_c2000k1000_masked_01.AUCPR1, '+r')
pl.plot(
    (10**-3, 1),
    (10**-3, 1)
)
pl.show()
